# %%
import importlib
# %load_ext autoreload
# %autoreload 2

# %%
import smartdata_setup

# Main


baseline_2010 = (1, 2010, 15, "base", "Base", "baseline", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2010__2019-09-20_21-12-45")
#base_2030lt_2010 = (2, 2010, 15, "base", "2030 Low Tech", "base_fleet_2030_lt", "beam/sfbay-smart-base-2030-lt-pilates__2019-09-11_04-49-22")
#base_2030ht_2010 = (3, 2010, 15, "base", "2030 High Tech", "base_fleet_2030_ht", "beam/sfbay-smart-base-2030-ht-pilates__2019-09-11_04-50-11")
#base_2045lt_2010 = (4, 2010, 15, "base", "2045 Low Tech", "base_fleet_2045_lt", "beam/sfbay-smart-base-2045-lt-pilates__2019-09-11_04-51-06")
#base_2045ht_2010 = (5, 2010, 15, "base", "2045 High Tech", "base_fleet_2045_ht", "beam/sfbay-smart-base-2045-ht-pilates__2019-09-11_04-51-47")
a_lt_2010 = (6, 2010, 15, "a", "Low Tech", "a_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-a-lt-2010__2019-09-20_21-12-45")
a_ht_2010 = (7, 2010, 15, "a", "High Tech", "a_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-a-ht-2010__2019-09-20_21-12-45")
b_lt_2010 = (8, 2010, 15, "b", "Low Tech", "b_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-b-lt-2010__2019-09-20_21-12-45")
b_ht_2010 = (9, 2010, 15, "b", "High Tech", "b_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-b-ht-2010__2019-09-20_21-12-46")
c_lt_2010 = (10, 2010, 15, "c", "Low Tech", "c_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-c-lt-2010__2019-09-20_21-12-45")
c_ht_2010 = (11, 2010, 15, "c", "High Tech", "c_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-c-ht-2010__2019-09-20_21-12-45")


baseline_2025 = (1, 2025, 15, "base", "Base", "baseline", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2025__2019-09-20_21-12-45")
base_2030lt_2025 = (2, 2025, 15, "base", "2030 Low Tech", "base_fleet_2030_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2030-lt-2025__2019-09-20_21-13-01")
base_2030ht_2025 = (3, 2025, 15, "base", "2030 High Tech", "base_fleet_2030_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2030-ht-2025__2019-09-20_21-13-12")
#base_2045lt_2025 = (4, 2025, 15, "base", "2045 Low Tech", "base_fleet_2045_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2045-lt-2025__2019-09-20_21-13-13")
#base_2045ht_2025 = (5, 2025, 15, "base", "2045 High Tech", "base_fleet_2045_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2045-ht-2025__2019-09-20_22-41-25")
a_lt_2025 = (6, 2025, 15, "a", "Low Tech", "a_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-a-lt-2025__2019-09-20_21-12-45")
a_ht_2025 = (7, 2025, 15, "a", "High Tech", "a_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-a-ht-2025__2019-09-20_21-12-45")
#b_lt_2025 = (8, 2025, 15, "b", "Low Tech", "b_lt", "beam/sfbay-smart-b-lt-pilates__2019-09-12_18-51-38")
#b_ht_2025 = (9, 2025, 15, "b", "High Tech", "b_ht", "beam/sfbay-smart-b-ht-pilates__2019-09-12_20-27-39")
#c_lt_2025 = (10, 2025, 15, "c", "Low Tech", "c_lt", "beam/sfbay-smart-c-lt-pilates__2019-09-12_18-53-11")
#c_ht_2025 = (11, 2025, 15, "c", "High Tech", "c_ht", "beam/sfbay-smart-c-ht-pilates__2019-09-12_18-54-51")


baseline_2040 = (1, 2040, 15, "base", "Base", "baseline", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2040__2019-09-20_21-12-45")
#base_2030lt_2040 = (2, 2040, 15, "base", "2030 Low Tech", "base_fleet_2030_lt", "beam/sfbay-smart-base-2030-lt-pilates__2019-09-13_18-06-04")
#base_2030ht_2040 = (3, 2040, 15, "base", "2030 High Tech", "base_fleet_2030_ht", "beam/sfbay-smart-base-2030-ht-pilates__2019-09-13_17-47-43")
base_2045lt_2040 = (4, 2040, 15, "base", "2045 Low Tech", "base_fleet_2045_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2045-lt-2040__2019-09-22_19-47-05")
base_2045ht_2040 = (5, 2040, 15, "base", "2045 High Tech", "base_fleet_2045_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-base-2045-ht-2040__2019-09-22_19-47-05")
#a_lt_2040 = (6, 2040, 15, "a", "Low Tech", "a_lt", "beam/sfbay-smart-a-lt-pilates__2019-09-13_13-44-02")
#a_ht_2040 = (7, 2040, 15, "a", "High Tech", "a_ht", "beam/sfbay-smart-a-ht-pilates__2019-09-13_13-39-31")
b_lt_2040 = (8, 2040, 15, "b", "Low Tech", "b_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-b-lt-2040__2019-09-20_21-12-45")
b_ht_2040 = (9, 2040, 15, "b", "High Tech", "b_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-b-ht-2040__2019-09-20_21-12-45")
c_lt_2040 = (10, 2040, 15, "c", "Low Tech", "c_lt", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-c-lt-2040__2019-09-20_21-12-45")
c_ht_2040 = (11, 2040, 15, "c", "High Tech", "c_ht", "https://beam-outputs.s3.amazonaws.com/output/sfbay/sfbay-smart-c-ht-2040__2019-09-20_21-12-45")


scenarios_2010 = [baseline_2010, a_lt_2010, a_ht_2010, b_lt_2010, b_ht_2010, c_lt_2010, c_ht_2010]
scenarios_2025 = [baseline_2025, base_2030lt_2025, base_2030ht_2025,
                  a_lt_2025, a_ht_2025]
scenarios_2040 = [baseline_2040,base_2045lt_2040, base_2045ht_2040, b_lt_2040, b_ht_2040, c_lt_2040, c_ht_2040]

scenarios = scenarios_2010 + scenarios_2025 + scenarios_2040

setup_config_dict = {
    "base_url": "https://beam-outputs.s3.amazonaws.com/pilates-outputs/15thSep2019",
    "run_name": "20thSep2019",
    "home_dir": "/home/ubuntu/git/jupyter/data",
    "scenarios": scenarios
}


smartdata_setup.make_plots(setup_config_dict)


print("END")
# Out:
# END

# %%
import pandas as pd
import smartplots3_setup

def createSetup(name,expansion_factor,plot_size,settings):
    plt_setup_smart={
    'name': name,
    'expansion_factor':expansion_factor,
    'scenarios_itr': [],
    'scenarios_id':[],
    'scenarios_year':[],
    'plot_size': plot_size,
    'bottom_labels': bottom_labels,
    'top_labels': [],
    }
    plt_setup_smart['name']=name
    plt_setup_smart['expansion_factor']=expansion_factor
    plt_setup_smart['plot_size']=plot_size
    
    plt_setup_smart['scenarios_year']=[]
    plt_setup_smart['scenarios_id']=[]
    plt_setup_smart['scenarios_itr']=[]
    plt_setup_smart['top_labels']=[]
    
    for (scenarios_year,scenarios_id,scenarios_itr,bottom_label,top_label) in settings:
        plt_setup_smart['scenarios_year'].append(scenarios_year)
        plt_setup_smart['scenarios_id'].append(scenarios_id)
        plt_setup_smart['scenarios_itr'].append(scenarios_itr)
        plt_setup_smart['top_labels'].append(top_label)
        plt_setup_smart['bottom_labels'].append(bottom_label)
    
    return plt_setup_smart

def createSettingRow(scenarios_year,scenarios_id,scenarios_itr,bottom_label,top_label):
    return (scenarios_year,scenarios_id,scenarios_itr,bottom_label,top_label)
    
settings=[]
settings.append(createSettingRow(2010,1,15,"Base_CL_CT", ""))
settings.append(createSettingRow(2025,6,15,"A_STL_STT_BAU", ""))
settings.append(createSettingRow(2025,7,15,"A_STL_STT_VTO", ""))
settings.append(createSettingRow(2040,8,15,"B_LTL_LTT_BAU", ""))
settings.append(createSettingRow(2040,9,15,"B_LTL_LTT_VTO", ""))
settings.append(createSettingRow(2040,10,15,"C_LTL_LTT_BAU", ""))
settings.append(createSettingRow(2040,11,15,"C_LTL_LTT_VTO", ""))
plt_setup_smart2 = createSetup('7scenarios',(7.75/0.315) * 27.0 / 21.3,(5, 4.5),settings)


output_folder = "/home/ubuntu/git/jupyter/data/20thSep2019"

smartplots3_setup.pltAveragePersonSpeed_allModes(plt_setup_smart2, output_folder)
smartplots3_setup.pltAveragePersonSpeed_car(plt_setup_smart2, output_folder)
smartplots3_setup.pltAverageLDVSpeed(plt_setup_smart2, output_folder)
smartplots3_setup.pltModeSplitByTrips(plt_setup_smart2, output_folder)
smartplots3_setup.tableSummary(plt_setup_smart2, output_folder)

smartplots3_setup.pltLdvRhOccupancy(plt_setup_smart2, output_folder)
smartplots3_setup.pltModeSplitInPMT(plt_setup_smart2, output_folder)
smartplots3_setup.pltModeSplitInPMTPerCapita(plt_setup_smart2, output_folder)
smartplots3_setup.pltLdvTechnologySplitInVMT(plt_setup_smart2, output_folder)
smartplots3_setup.pltModeSplitInVMT(plt_setup_smart2, output_folder)
smartplots3_setup.pltModeSplitInVMT_withoutNonMotorizedMode(plt_setup_smart2, output_folder)
smartplots3_setup.pltModeSplitInVMTPerCapita(plt_setup_smart2, output_folder)
smartplots3_setup.pltModeSplitInVMTPerCapita_withoutNonMotorizedMode(plt_setup_smart2, output_folder)
smartplots3_setup.pltRHEmptyPooled(plt_setup_smart2, output_folder)
smartplots3_setup.pltLdvRhOccupancyByVMT(plt_setup_smart2, output_folder)
smartplots3_setup.pltOverallAverageSpeed(plt_setup_smart2, output_folder)
smartplots3_setup.pltRHWaitTime(plt_setup_smart2, output_folder)

settings=[]
settings.append(createSettingRow(2010,1,15,"Base"))
settings.append(createSettingRow(2025,2,15,"BAU"))
settings.append(createSettingRow(2025,3,15,"VTO"))
settings.append(createSettingRow(2040,4,15,"BAU"))
settings.append(createSettingRow(2040,5,15,"VTO"))
settings.append(createSettingRow(2025,6,15,"BAU"))
settings.append(createSettingRow(2025,7,15,"VTO"))
settings.append(createSettingRow(2040,8,15,"BAU"))
settings.append(createSettingRow(2040,9,15,"VTO"))
settings.append(createSettingRow(2040,10,15,"BAU"))
settings.append(createSettingRow(2040,11,15,"VTO"))
plt_setup_smart2_base = createSetup('11scenarios',settings,(7.75/0.315) * 27.0 / 21.3,(7.5, 4.5),['Base', 'Base Short','Base Long', 'Sharing is Caring', 'Technology Takeover', "All About Me"])


smartplots3_setup.pltEnergyPerCapita(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltLdvPersonHourTraveled(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
smartplots3_setup.tableSummary(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMT_withoutNonMotorizedMode(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltAverageLDVSpeed(plt_setup_smart2_base, output_folder)


settings=[]
settings.append(createSettingRow(2010,1,15,"Base"))
settings.append(createSettingRow(2025,1,15,"Base"))
settings.append(createSettingRow(2040,1,15,"Base"))
plt_setup_smart2_base = createSetup('3base',settings,(7.75/0.315) * 27.0 / 21.3,(7.5, 4.5),['Base-2010', 'Base-2025','Base-2040'])
smartplots3_setup.pltAveragePersonSpeed_allModes(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltAveragePersonSpeed_car(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltAverageLDVSpeed(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitByTrips(plt_setup_smart2_base, output_folder)
smartplots3_setup.tableSummary(plt_setup_smart2_base, output_folder)

smartplots3_setup.pltLdvRhOccupancy(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInPMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInPMTPerCapita(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltLdvTechnologySplitInVMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMT_withoutNonMotorizedMode(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMTPerCapita(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMTPerCapita_withoutNonMotorizedMode(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltRHEmptyPooled(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltLdvRhOccupancyByVMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltOverallAverageSpeed(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltEnergyPerCapita(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltLdvPersonHourTraveled(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
smartplots3_setup.tableSummary(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMT_withoutNonMotorizedMode(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltAverageLDVSpeed(plt_setup_smart2_base, output_folder)


settings=[]
settings.append(createSettingRow(2010,1,15,"Base"))
settings.append(createSettingRow(2010,6,15,"BAU"))
settings.append(createSettingRow(2010,7,15,"VTO"))
settings.append(createSettingRow(2010,8,15,"BAU"))
settings.append(createSettingRow(2010,9,15,"VTO"))
settings.append(createSettingRow(2010,10,15,"BAU"))
settings.append(createSettingRow(2010,11,15,"VTO"))
plt_setup_smart2_base = createSetup('all2010',settings,(7.75/0.315) * 27.0 / 21.3,(7.5, 4.5),['Base', 'Base Short','Base Long', 'Sharing is Caring', 'Technology Takeover', "All About Me"])
smartplots3_setup.pltAveragePersonSpeed_allModes(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltAveragePersonSpeed_car(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltAverageLDVSpeed(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitByTrips(plt_setup_smart2_base, output_folder)
smartplots3_setup.tableSummary(plt_setup_smart2_base, output_folder)

smartplots3_setup.pltLdvRhOccupancy(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInPMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInPMTPerCapita(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltLdvTechnologySplitInVMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMT_withoutNonMotorizedMode(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMTPerCapita(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMTPerCapita_withoutNonMotorizedMode(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltRHEmptyPooled(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltLdvRhOccupancyByVMT(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltOverallAverageSpeed(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltEnergyPerCapita(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltLdvPersonHourTraveled(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
smartplots3_setup.tableSummary(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltModeSplitInVMT_withoutNonMotorizedMode(plt_setup_smart2_base, output_folder)
smartplots3_setup.pltAverageLDVSpeed(plt_setup_smart2_base, output_folder)
# Out:
# /home/ubuntu/git/jupyter/smartplots3_setup.py:56: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([df, df_temp[df_temp['Rank'] == id]])
# /home/ubuntu/git/jupyter/smartplots3_setup.py:56: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([df, df_temp[df_temp['Rank'] == id]])
# /home/ubuntu/git/jupyter/smartplots3_setup.py:56: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# ...

# %%
import os
#os.remove("data/20thSep2019/2010.15.metrics-final.csv")
#os.remove("data/20thSep2019/2025.15.metrics-final.csv")
os.remove("data/20thSep2019/2040.15.metrics-final.csv")

# %%
import os
import glob
 
# Get a list of all the file paths that ends with .txt from in specified directory
#fileList = glob.glob('data/20thSep2019/*metrics*')
#fileList = glob.glob('data/20thSep2019/*2040-15.metrics.csv')
#fileList = glob.glob('data/20thSep2019/*2040-15.pooling-metrics.json')
#fileList = glob.glob('data/20thSep2019/*2040-15.all-metrics.json')
#fileList = glob.glob('data/20thSep2019/*2040.15.metrics-final.csv')
    
    
    
# Iterate over the list of filepaths & remove each file.
for filePath in fileList:
    try:
        os.remove(filePath)
    except:
        print("Error while deleting file : ", filePath)

# %%
import pandas as pd
import smartplots2_setup





plt_setup_smart2 = {
    'name': '7scenarios',
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,

    'scenarios_itr': [15, 15, 15, 15, 15, 15, 15],
    'scenarios_id': [1, 6, 7, 8, 9, 10, 11],
    'scenarios_year': [2010, 2025, 2025, 2040, 2040, 2040, 2040],

    'plot_size': (6, 4),
    'bottom_labels': ['Base', 'Sharing is Caring', 'Technology Takeover', "All About Me"],
    'top_labels': ["Base", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO"],
}

output_folder = "C:/Users/NRO_M4700_SSD_02/JupyterLab/pilates/analysis/data/20thSep2019"


# smartplots2_setup.pltModeSplitByTrips(plt_setup_smart2, output_folder)
# smartplots2_setup.tableSummary(plt_setup_smart2, output_folder)

# smartplots2_setup.pltLdvRhOccupancy(plt_setup_smart2, output_folder)
# smartplots2_setup.pltModeSplitInPMT(plt_setup_smart2, output_folder)
# smartplots2_setup.pltModeSplitInPMTPerCapita(plt_setup_smart2, output_folder)
# smartplots2_setup.pltLdvTechnologySplitInVMT(plt_setup_smart2, output_folder)
# smartplots2_setup.pltModeSplitInVMT(plt_setup_smart2, output_folder)
# smartplots2_setup.pltModeSplitInVMTPerCapita(plt_setup_smart2, output_folder)
# smartplots2_setup.pltRHEmptyPooled(plt_setup_smart2, output_folder)
# smartplots2_setup.pltLdvRhOccupancyByVMT(plt_setup_smart2, output_folder)


plt_setup_smart2_base = {
    'name': '11scenarios',
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,

    'scenarios_itr': [15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15],
    'scenarios_id': [1, 2, 3, 6, 7, 8, 9, 10, 11],
    'scenarios_year': [2010, 2025, 2025, 2025, 2025, 2040, 2040, 2040, 2040],

    'plot_size': (7.5, 4),
    'bottom_labels': ['Base', 'Base Short','Base Long', 'Sharing is Caring', 'Technology Takeover', "All About Me"],
    'top_labels': ["Base", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO"],
}

smartplots2_setup.pltEnergyPerCapita(plt_setup_smart2_base, output_folder)
smartplots2_setup.pltLdvPersonHourTraveled(plt_setup_smart2_base, output_folder)
smartplots2_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-a61d229ba5f1> in <module>
#      48 }
#      49
# ---> 50 smartplots2_setup.pltEnergyPerCapita(plt_setup_smart2_base, output_folder)
#      51 smartplots2_setup.pltLdvPersonHourTraveled(plt_setup_smart2_base, output_folder)
#      52 smartplots2_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
#
# ~/git/jupyter/smartplots2_setup.py in pltEnergyPerCapita(_plt_setup2, _output_folder)
#     711     scale = 1 / 1000000000
#     712     angle = 12
# --> 713     (df, top_labels_xpos, bottom_labels_xpos) = getDfForPlt(_plt_setup2, _output_folder)
#     714     output_png = '{}/makeplots/{}.energy_source_percapita.png'.format(_output_folder, _plt_setup2['name'])
#     715     output_csv = '{}/makeplots/{}.energy_source_percapita.csv'.format(_output_folder, _plt_setup2['name'])
#
# ...

# %%
# Out:
# C:\Users\NRO_M4700_SSD_02\JupyterLab\pilates\analysis\smartplots2_setup.py:55: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([df, df_temp[df_temp['Rank'] == id]])
# C:\Users\NRO_M4700_SSD_02\JupyterLab\pilates\analysis\smartplots2_setup.py:55: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([df, df_temp[df_temp['Rank'] == id]])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
import smartplots2_setup

def createSetup(name,settings,expansion_factor,plot_size,bottom_labels):
    plt_setup_smart={
    'name': name,
    'expansion_factor':expansion_factor,
    'scenarios_itr': [],
    'scenarios_id':[],
    'scenarios_year':[],
    'plot_size': plot_size,
    'bottom_labels': bottom_labels,
    'top_labels': [],
    }
    plt_setup_smart['name']=name
    plt_setup_smart['expansion_factor']=expansion_factor
    plt_setup_smart['plot_size']=plot_size
    plt_setup_smart['bottom_labels']=bottom_labels
    
    plt_setup_smart['scenarios_year']=[]
    plt_setup_smart['scenarios_id']=[]
    plt_setup_smart['scenarios_itr']=[]
    plt_setup_smart['top_labels']=[]
    
    for (scenarios_year,scenarios_id,scenarios_itr,top_labels) in settings:
        plt_setup_smart['scenarios_year'].append(scenarios_year)
        plt_setup_smart['scenarios_id'].append(scenarios_id)
        plt_setup_smart['scenarios_itr'].append(scenarios_itr)
        plt_setup_smart['top_labels'].append(top_labels)
    
    return plt_setup_smart

def createSettingRow(scenarios_year,scenarios_id,scenarios_itr,top_labels):
    return (scenarios_year,scenarios_id,scenarios_itr,top_labels)
    
settings=[]
settings.append(createSettingRow(2010,1,15,"Base"))

plt_setup_smart2 = createSetup('7scenarios',settings,(7.75/0.315) * 27.0 / 21.3,(5, 4.5),["Base", "Sharing is Caring", "Technology Takeover", "All About Me"])



output_folder = "C:/Users/NRO_M4700_SSD_02/JupyterLab/pilates/analysis/data/20thSep2019"



smartplots2_setup.pltModeSplitByTrips(plt_setup_smart2, output_folder)
smartplots2_setup.tableSummary(plt_setup_smart2, output_folder)

smartplots2_setup.pltLdvRhOccupancy(plt_setup_smart2, output_folder)
smartplots2_setup.pltModeSplitInPMT(plt_setup_smart2, output_folder)
smartplots2_setup.pltModeSplitInPMTPerCapita(plt_setup_smart2, output_folder)
smartplots2_setup.pltLdvTechnologySplitInVMT(plt_setup_smart2, output_folder)
smartplots2_setup.pltModeSplitInVMT(plt_setup_smart2, output_folder)
smartplots2_setup.pltModeSplitInVMTPerCapita(plt_setup_smart2, output_folder)
smartplots2_setup.pltRHEmptyPooled(plt_setup_smart2, output_folder)
smartplots2_setup.pltLdvRhOccupancyByVMT(plt_setup_smart2, output_folder)

settings=[]
settings.append(createSettingRow(2010,1,15,"Base"))
plt_setup_smart2_base = createSetup('11scenarios',settings,(7.75/0.315) * 27.0 / 21.3,(7.5, 4.5),['Base', 'Base Short','Base Long', 'Sharing is Caring', 'Technology Takeover', "All About Me"])


smartplots2_setup.pltEnergyPerCapita(plt_setup_smart2_base, output_folder)
smartplots2_setup.pltLdvPersonHourTraveled(plt_setup_smart2_base, output_folder)
smartplots2_setup.pltRHWaitTime(plt_setup_smart2_base, output_folder)
smartplots2_setup.tableSummary(plt_setup_smart2_base, output_folder)

# %%
from smartplots_setup import pltModeSplitByTrips
from smartplots_setup import pltEnergyPerCapita
from smartplots_setup import pltLdvRhOccupancy
from smartplots_setup import pltLdvPersonHourTraveled
from smartplots_setup import pltModeSplitInPMT
from smartplots_setup import pltModeSplitInVMT
from smartplots_setup import pltLdvTechnologySplitInVMT
from smartplots_setup import pltRHWaitTime
from smartplots_setup import pltRHEmptyPooled
from smartplots_setup import pltLdvRhOccupancyByVMT
from smartplots_setup import tableSummary
import pandas as pd



plt_setup_base_smart2010 = {
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,
    'rotation': 13,
    'fig_size': (7.5, 4.5),
    'scenarios': ['Base', 'Base-Short', 'Base-Long', 'Sharing is Caring', 'Technology Takeover', "All About Me"],
    'scenarios_xpos': [1, 3.5, 6.5, 9.5, 12.5, 15.5],
    'technologies': ["Base", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO","BAU", "VTO"],
    'technologies_xpos': [1, 6, 7,8, 9, 10, 11 ],
    'dimension': 7,
    'rank_to_filterout': []
}


plt_setup_smart2010 = {
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,
    'rotation': 11,
    'fig_size': (5, 4.5),
    'scenarios': ['Base','Sharing is Caring', 'Technology Takeover', "All About Me"],
    'scenarios_xpos': [1, 3.5, 6.5, 9.5],
    'technologies': ["Base","BAU", "VTO", "BAU", "VTO", "BAU", "VTO"],
    'technologies_xpos': [1, 6,7,8,9,10,11],
    'dimension': 7,
    'rank_to_filterout': []
}

plt_setup_base_smart2025 = {
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,
    'rotation': 13,
    'fig_size': (7.5, 4.5),
    'scenarios': ['Base', 'Base-Short', 'Base-Long', 'Sharing is Caring', 'Technology Takeover', "All About Me"],
    'scenarios_xpos': [1, 3.5, 6.5, 9.5, 12.5, 15.5],
    'technologies': ["Base", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO", "BAU", "VTO","BAU", "VTO"],
    'technologies_xpos': [1, 6, 7,8, 9, 10, 11 ],
    'dimension': 7,
    'rank_to_filterout': []
}


plt_setup_smart2025 = {
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,
    'rotation': 11,
    'fig_size': (5, 4.5),
    'scenarios': ['Base','Sharing is Caring', 'Technology Takeover', "All About Me"],
    'scenarios_xpos': [1, 3.5, 6.5, 9.5],
    'technologies': ["Base","BAU", "VTO", "BAU", "VTO", "BAU", "VTO"],
    'technologies_xpos': [1, 6,7,8,9,10,11],
    'dimension': 7,
    'rank_to_filterout': []
}

plt_setup_base_smart2040 = {
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,
    'rotation': 13,
    'fig_size':  (7.5, 4.5),
    'scenarios': ['Base', 'Technology Takeover', "All About Me"],
    'scenarios_xpos': [1, 3.5, 6.5, 9.5],
    'technologies': ["Base", "VTO", "BAU", "VTO","BAU", "VTO"],
    'technologies_xpos': [1,8, 9, 10, 11 ],
    'dimension': 5,
    'rank_to_filterout': [2,3,4,5,6,7]
}


plt_setup_smart2040 = {
    'expansion_factor': (7.75/0.315) * 27.0 / 21.3,
    'rotation': 11,
    'fig_size': (5, 4.5),
    'scenarios': ['Base', 'Technology Takeover', "All About Me"],
    'scenarios_xpos': [1, 3.5, 6.5, 9.5],
    'technologies': ["Base", "BAU", "VTO", "BAU", "VTO"],
    'technologies_xpos': [1, 8,9,10,11],
    'dimension': 5,
    'rank_to_filterout': [2,3,4,5,6,7]
}

def makePlots(year,plt_setup_smart,plt_setup_base_smart):
    output_folder = "C:/Users/NRO_M4700_SSD_02/JupyterLab/pilates/analysis/data/20thSep2019"
    #year = "2010"
    iteration = "15"
    prefix = "{}.{}".format(year, iteration)
    metrics_file = "{}/{}.metrics-final.csv".format(output_folder, prefix)

    df = pd.read_csv(metrics_file).fillna(0)

    tableSummary(plt_setup_smart, df, output_folder, prefix)

    pltModeSplitByTrips(plt_setup_smart, df, output_folder, prefix)
    pltLdvRhOccupancy(plt_setup_smart, df, output_folder, prefix)
    pltModeSplitInPMT(plt_setup_smart, df, output_folder, prefix)
    pltLdvTechnologySplitInVMT(plt_setup_smart, df, output_folder, prefix)
    pltModeSplitInVMT(plt_setup_smart, df, output_folder, prefix)
    pltRHEmptyPooled(plt_setup_smart, df, output_folder, prefix)
    pltLdvRhOccupancyByVMT(plt_setup_smart, df, output_folder, prefix)

    pltEnergyPerCapita(plt_setup_base_smart, df, output_folder, prefix)
    pltLdvPersonHourTraveled(plt_setup_base_smart, df, output_folder, prefix)
    pltRHWaitTime(plt_setup_base_smart, df, output_folder, prefix)

    
makePlots(2010,plt_setup_smart2010,plt_setup_base_smart2010)
#makePlots(2025,plt_setup_smart2025,plt_setup_base_smart2025)
#makePlots(2040,plt_setup_smart2040,plt_setup_base_smart2040)
# Out:
# ddd

# %%
#no-futuristic-base.rh_empty_shared.png -> debug, why?
