# %%
import pandas as pd

# %%
pd.read_csv('capmetro-0pt5/calendar.txt')
# Out:
#       service_id  monday  tuesday  wednesday  thursday  friday  saturday  \
# 0    1-133_MRG_1       1        1          1         1       1         0
# 1   1-133_MRG_10       1        1          1         1       1         0
# 2   1-133_MRG_11       1        1          1         1       1         0
# 3   1-133_MRG_12       1        1          1         1       1         0
# 4   1-133_MRG_13       1        1          1         1       1         0
# ..           ...     ...      ...        ...       ...     ...       ...
# 72   5-133_MRG_1       0        0          0         0       0         0
# 73   5-133_MRG_2       0        0          0         0       0         0
# 74   5-133_MRG_3       0        0          0         0       0         0
# 75   5-133_MRG_4       0        0          0         0       0         0
# 76   5-133_MRG_5       0        0          0         0       0         0
#
#     sunday  start_date  end_date
# 0        0    20200122  20200530
# ...

# %%
pd.read_csv('capmetro-0pt5/routes.txt')
# Out:
#     agency_id  route_id  route_short_name             route_long_name  \
# 0           1         1                 1  North Lamar/South Congress
# 1           1        10                10         South 1st/Red River
# 2           1       103               103              Menchaca Flyer
# 3           1       105               105             South 5th Flyer
# 4           1       111               111           South Mopac Flyer
# ..        ...       ...               ...                         ...
# 79          1       981               981           Oak Knoll Express
# 80          1       982               982            Pavilion Express
# 81          1       985               985     Leander/Lakeline Direct
# 82          1       987               987    Leander/Lakeline Express
# 83          1       990               990         Manor/Elgin Express
#
#     route_type                                          route_url route_color  \
# ...

# %%
trips = pd.read_csv('capmetro-0pt5/trips.txt')

# %%
trips
# Out:
#        route_id         trip_id      service_id trip_short_name  \
# 0             1   2277027_MRG_1     1-133_MRG_1  William Cannon
# 1             1  2277027_MRG_11    1-133_MRG_11  William Cannon
# 2             1  2277027_MRG_13    1-133_MRG_13  William Cannon
# 3             1  2277027_MRG_14    1-133_MRG_14  William Cannon
# 4             1   2277027_MRG_3     1-133_MRG_3  William Cannon
# ...         ...             ...             ...             ...
# 58487       663   2313858_MRG_1  4904-133_MRG_1       UT Campus
# 58488       663   2313861_MRG_1  4904-133_MRG_1       UT Campus
# 58489       663   2313863_MRG_1  4904-133_MRG_1       UT Campus
# 58490       663   2313864_MRG_1  4904-133_MRG_1       UT Campus
# 58491       663   2313868_MRG_1  4904-133_MRG_1       UT Campus
#
#                    trip_headsign  direction_id               block_id  \
# 0      1-Lamar/South Congress SB             0       1007-1-133_MRG_1
# ...

# %%
type(trips[trips['service_id'] == '1-133_MRG_1']['route_id'][0])
# Out:
# numpy.int64

# %%
pd.read_csv('capmetro-0pt5-out/trips.txt')
# Out:
#        route_id         trip_id    service_id      trip_short_name  \
# 0             1   2277027_MRG_1   1-133_MRG_1       William Cannon
# 1             1  2277027_MRG_11  1-133_MRG_11       William Cannon
# 2             1  2277027_MRG_13  1-133_MRG_13       William Cannon
# 3             1  2277027_MRG_14  1-133_MRG_14       William Cannon
# 4             1   2277028_MRG_1   1-133_MRG_1       William Cannon
# ...         ...             ...           ...                  ...
# 18071       465  2313348_MRG_15  1-133_MRG_15  University of Texas
# 18072       465   2313349_MRG_1   1-133_MRG_1          MLK Station
# 18073       465  2313349_MRG_12  1-133_MRG_12          MLK Station
# 18074       465  2313349_MRG_13  1-133_MRG_13          MLK Station
# 18075       465  2313349_MRG_14  1-133_MRG_14          MLK Station
#
#                         trip_headsign  direction_id             block_id  \
# 0           1-Lamar/South Congress SB             0     1007-1-133_MRG_1
# ...
