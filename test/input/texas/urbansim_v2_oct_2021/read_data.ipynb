# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
blocks = pd.read_csv('blocks.csv.gz')
display(blocks.head())
display(blocks.columns)
households = pd.read_csv('households.csv.gz')
display(households)
display(households.columns)
persons = pd.read_csv('persons.csv.gz')
display(persons)
display(persons.columns)
plans = pd.read_csv('plans.csv.gz')
display(plans)
display(plans.columns)
trips = pd.read_csv('trips.csv.gz')
display(trips)
display(trips.columns)
# Out:
#    Unnamed: 0         block_id         taz_id  res_rents  zone_id  \
# 0           0  480219501003014  4802100001389      525.0     1389
# 1           1  480219501003015  4802100001389      525.0     1389
# 2           2  480219503005030  4802100001171      940.0     2192
# 3           3  480219502004004  4802100001214      350.0     1214
# 4           4  480219505021143  4802100001157      820.0     1157
#
#    square_meters_land  employment_capacity  puma10_id          y  \
# 0             7234430                 3575    4805100  30.213914
# 1                2623                    1    4805100  30.220892
# 2              205922                  102    4805100  30.105624
# 3               27387                   14    4805100  30.345393
# 4             1124252                  556    4805100  30.072865
#
#    value_impute          x  residential_unit_capacity  \
# 0             0 -97.429419                       6257
# 1             1 -97.432013                          2
# ...

# %%
persons['student'].unique()
# Out:
# array([0, 1])

# %%
persons['value_of_time'].unique()
# Out:
# array([2.94206011, 8.38072341, 1.70339387, ..., 2.65277807, 1.76940297,
#        3.55145893])
