# %%
import pandas as pd
pd.set_option("display.max_column", None)

# %%
plan = pd.read_csv('plans.csv.gz')

# %%
plan
# Out:
#       personId planElement  planElementIndex activityType           x  \
# 0      5575738    activity                 1         Home -122.443522
# 1      5575738         leg                 2          NaN         NaN
# 2      5575738    activity                 3         Work -122.432516
# 3      5575738         leg                 4          NaN         NaN
# 4      5575738    activity                 5         Home -122.443522
# ...        ...         ...               ...          ...         ...
# 5840   6350862    activity                 1         Home -122.480908
# 5841   6350862         leg                 2          NaN         NaN
# 5842   6350862    activity                 3         Work -122.436245
# 5843   6350862         leg                 4          NaN         NaN
# 5844   6350862    activity                 5         Home -122.480908
#
#               y    endTime  mode
# 0     37.805045   7.293863   NaN
# 1           NaN        NaN   NaN
# ...
