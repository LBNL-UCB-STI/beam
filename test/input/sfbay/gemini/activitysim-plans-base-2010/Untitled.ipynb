# %%
import pandas as pd

# %%
pd.read_csv('blocks.csv.gz')
# Out:
#         Unnamed: 0        block_id          y  value_impute        taz_id  \
# 0                0  60014271001000  37.770270             1  6.001001e+11
# 1                1  60014271001001  37.769464             0  6.001001e+11
# 2                2  60014271001002  37.768350             1  6.001001e+11
# 3                3  60014271001003  37.768827             0  6.001001e+11
# 4                4  60014271001004  37.769734             0  6.001001e+11
# ...            ...             ...        ...           ...           ...
# 109223      109223  60971505004042  38.368332             1  6.097001e+11
# 109224      109224  60971505004043  38.394669             0  6.097001e+11
# 109225      109225  60971505004044  38.346177             0  6.097001e+11
# 109226      109226  60971505004045  38.348465             0  6.097001e+11
# 109227      109227  60971505004046  38.371593             1  6.097001e+11
#
#         square_meters_land  res_rents  rent_impute  residential_unit_capacity  \
# ...

# %%
pd.read_csv('final_land_use.csv')
# Out:
#        TAZ  objectid  district         county        gacres  Shape__Area  \
# 0        1       339         1  San Francisco     32.530647     0.000008
# 1        2       416         1  San Francisco     49.911128     0.000013
# 2        3       340         1  San Francisco     23.589885     0.000006
# 3        4       417         1  San Francisco     30.883590     0.000008
# 4        5       341         1  San Francisco     84.606743     0.000022
# ...    ...       ...       ...            ...           ...          ...
# 1449  1450      1038        34          Marin   3564.505472     0.000919
# 1450  1451      1039        34          Marin   1572.514038     0.000405
# 1451  1452      1037        34          Marin   1746.060818     0.000450
# 1452  1453       935        34          Marin  22961.995001     0.005919
# 1453  1454       936        34          Marin  16930.613457     0.004361
#
#       Shape__Length                                           geometry  \
# ...

# %%
pd.read_csv('final_persons.csv')
# Out:
#         person_id  age  earning   edu  hispanic  hours  PNUM  race_id  relate  \
# 0            2418   27  32000.0  21.0         0   24.0     1        1       0
# 1            2419   27  68000.0  21.0         0   50.0     2        9      13
# 2            3218   52  27000.0   8.0         0   40.0     3        1       2
# 3            3219   72      0.0  16.0         0    0.0     1        1       0
# 4            3220   82      0.0  16.0         0    0.0     2        1       1
# ...           ...  ...      ...   ...       ...    ...   ...      ...     ...
# 418755    6803437   15      0.0  11.0         0    0.0     2        1       2
# 418756    6803438   12      0.0   8.0         0    0.0     3        1       2
# 418757    6804218   55      0.0  14.0         0    0.0     1        1       0
# 418758    6805498   81      0.0  16.0         0    0.0     1        1       0
# 418759    6805499   79      0.0  16.0         0    0.0     2        1       1
#
# ...

# %%
pd.read_csv('households.csv').to_csv('households.csv.gz')

# %%
pd.read_csv('persons.csv').to_csv('persons.csv.gz')

# %%
pd.read_csv('trips.csv').to_csv('trips.csv.gz')

# %%
data = pd.read_csv('households.csv')

# %%
data['income'] = data['income'].astype(int)

# %%
data.to_csv('households.csv.gz')

# %%
data.columns
# Out:
# Index(['household_id', 'serialno', 'VEHICL', 'income', 'race_of_head',
#        'age_of_head', 'num_workers', 'hispanic_status_of_head', 'tenure',
#        'recent_mover', 'sf_detached', 'hh_age_of_head', 'hh_race_of_head',
#        'hispanic_head', 'hh_size', 'hh_cars', 'hh_children', 'seniors',
#        'hh_income', 'hh_workers', 'tenure_mover', 'hh_seniors', 'block_id',
#        'lcm_county_id', 'hhsize', 'gt55', 'gt2', 'hh_type', 'TAZ', 'HHT',
#        'sample_rate', 'chunk_id', 'income_in_thousands', 'income_segment',
#        'median_value_of_time', 'hh_value_of_time', 'num_non_workers',
#        'num_drivers', 'num_adults', 'num_children', 'num_young_children',
#        'num_children_5_to_15', 'num_children_16_to_17', 'num_college_age',
#        'num_young_adults', 'non_family', 'family', 'home_is_urban',
#        'home_is_rural', 'auto_ownership', 'hh_work_auto_savings_ratio',
#        'num_under16_not_at_school', 'num_travel_active',
# ...

# %%
data['cars']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cars'
#
# ...
