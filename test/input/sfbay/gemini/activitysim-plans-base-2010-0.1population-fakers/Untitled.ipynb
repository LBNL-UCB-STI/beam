# %%
import pandas as pd

# %%
households = pd.read_csv('households.csv.gz')

# %%
households
# Out:
#         Unnamed: 0  household_id  gt55  seniors  VEHICL  lcm_county_id  \
# 0                0       1860018     0      0.0       1           6085
# 1                1       1190176     1      0.0       2           6075
# 2                2       2271855     1      1.0       1           6085
# 3                3       2430363     1      1.0       1           6097
# 4                4       1835264     0      0.0       2           6085
# ...            ...           ...   ...      ...     ...            ...
# 274778      274778       2611258     0      0.0       2           6075
# 274779      274779        473427     0      0.0       2           6001
# 274780      274780        691402     0      0.0       1           6013
# 274781      274781       1640030     1      0.0       1           6081
# 274782      274782       1234871     0      1.0       1           6075
#
#        hh_children        block_id  gt2 hispanic_head  ...  \
# ...

# %%
households['VEHICL'].value_counts()
# Out:
# 2    108464
# 1    103328
# 3     37950
# 4     21613
# 0      3428
# Name: VEHICL, dtype: int64

# %%
import numpy as np

# %%
households['VEHICL'] = 100

# %%
households
# Out:
#         Unnamed: 0  household_id  gt55  seniors  VEHICL  lcm_county_id  \
# 0                0       1860018     0      0.0     100           6085
# 1                1       1190176     1      0.0     100           6075
# 2                2       2271855     1      1.0     100           6085
# 3                3       2430363     1      1.0     100           6097
# 4                4       1835264     0      0.0     100           6085
# ...            ...           ...   ...      ...     ...            ...
# 274778      274778       2611258     0      0.0     100           6075
# 274779      274779        473427     0      0.0     100           6001
# 274780      274780        691402     0      0.0     100           6013
# 274781      274781       1640030     1      0.0     100           6081
# 274782      274782       1234871     0      1.0     100           6075
#
#        hh_children        block_id  gt2 hispanic_head  ...  \
# ...

# %%
households.to_csv('households.csv.gz')

# %%
households.VEHICL = np.where(households.VEHICL == 0, 4, households.VEHICL)

# %%
households.VEHICL.value_counts()
# Out:
# 2    108464
# 1    103328
# 3     37950
# 4     25041
# Name: VEHICL, dtype: int64

# %%
households.to_csv('households.csv.gz')

# %%
households[households['VEHICL'] == 0]
# Out:
#         Unnamed: 0  household_id  gt55  seniors  VEHICL  lcm_county_id  \
# 63              63       2803327     1      1.0       0           6013
# 333            333        199038     0      0.0       0           6001
# 444            444       1074139     0      0.0       0           6075
# 499            499       2510055     0      0.0       0           6097
# 519            519       1342969     1      1.0       0           6075
# ...            ...           ...   ...      ...     ...            ...
# 274335      274335        334629     0      0.0       0           6001
# 274380      274380       1169585     0      0.0       0           6075
# 274434      274434       1319696     0      0.0       0           6075
# 274515      274515        412417     1      0.0       0           6001
# 274618      274618       1982606     0      0.0       0           6085
#
#        hh_children        block_id  gt2 hispanic_head  ...  \
# ...

# %%
households[]

# %%
data = pd.read_csv('plans.csv.gz')

# %%
data
# Out:
#          Unnamed: 0       trip_id  person_id  number_of_participants  \
# 0                 0           NaN        1.0                     NaN
# 1                 1  5.770000e+02        1.0                     1.0
# 2                 2           NaN        1.0                     NaN
# 3                 3  5.780000e+02        1.0                     1.0
# 4                 4           NaN        1.0                     NaN
# ...             ...           ...        ...                     ...
# 5703731     5703731           NaN  7399583.0                     NaN
# 5703732     5703732  2.427063e+09  7399583.0                     1.0
# 5703733     5703733           NaN  7399583.0                     NaN
# 5703734     5703734  2.427063e+09  7399583.0                     1.0
# 5703735     5703735           NaN  7399583.0                     NaN
#
#               trip_mode  PlanElementIndex ActivityElement ActivityType  \
# ...

# %%
data['trip_mode'].unique()
# Out:
# array([nan, 'SHARED2FREE', 'DRIVEALONEPAY', 'DRIVEALONEFREE',
#        'SHARED2PAY', 'SHARED3PAY', 'SHARED3FREE', 'WALK', 'WALK_LOC',
#        'BIKE', 'TNC_SINGLE', 'WALK_EXP', 'TAXI', 'WALK_LRF', 'WALK_HVY',
#        'TNC_SHARED', 'DRIVE_HVY', 'WALK_COM', 'DRIVE_LOC', 'DRIVE_LRF',
#        'DRIVE_EXP', 'DRIVE_COM'], dtype=object)
