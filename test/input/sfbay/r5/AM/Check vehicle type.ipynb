# %%
import pandas as pd

# %%
skimsTransitCrowding = pd.read_csv('1.String _ skimsTransitCrowding.csv.gz')

# %%
skimsTransitCrowding['firstTwo'] = skimsTransitCrowding['vehicleId'].str[:2]

# %%
skimsTransitCrowding['lastTen'] = skimsTransitCrowding['vehicleId'].str[-10:]

# %%
skimsTransitCrowding[skimsTransitCrowding['firstTwo'] == 'AM']
# Out:
#             vehicleId  fromStopIdx  numberOfPassengers  capacity  \
# 22      AM:RTD5982674            7                  43      1000
# 756     AM:RTD5982684            3                  47      1000
# 1232    AM:RTD5982654            4                  15      1000
# 1815    AM:RTD5982670            3                 110      1000
# 2112    AM:RTD5982682            0                   9      1000
# ...               ...          ...                 ...       ...
# 101634  AM:RTD5982654            3                  29      1000
# 102370  AM:RTD5982641            3                  87      1000
# 102535  AM:RTD5982679            4                  25      1000
# 102770  AM:RTD5982673           10                  39      1000
# 103114  AM:RTD5982682            4                  18      1000
#
#         observations  iterations firstTwo     lastTen
# 22                 1           1       AM  RTD5982674
# 756                1           1       AM  RTD5982684
# ...

# %%
trips = pd.read_csv('trips.txt')

# %%
trip_idlist = list(skimsTransitCrowding[skimsTransitCrowding['firstTwo'] == 'AM']['lastTen'])

# %%
trips['trip_id'].str[3:]
# Out:
# 0     5982640
# 1     5982641
# 2     6253554
# 3     8703586
# 4     8703564
#        ...
# 94    6253565
# 95    8703563
# 96    8703585
# 97    5982650
# 98    6253566
# Name: trip_id, Length: 99, dtype: object

# %%
AM = trips[trips['trip_id'].isin(skimsTransitCrowding[skimsTransitCrowding['firstTwo'] == 'AM']['lastTen'])]

# %%
AM
# Out:
#    route_id  service_id     trip_id     trip_headsign  direction_id  block_id  \
# 0   CAPITOL       72761  RTD5982640          SAN JOSE             0       NaN
# 1   CAPITOL       72761  RTD5982641          SAN JOSE             0       NaN
# 5   CAPITOL       72761  RTD5982642          SAN JOSE             0       NaN
# 12  CAPITOL       72761  RTD5982643          SAN JOSE             0       NaN
# 15  CAPITOL       72761  RTD5982644          SAN JOSE             0       NaN
# 20  CAPITOL       72761  RTD5982645          SAN JOSE             0       NaN
# 25  CAPITOL       72761  RTD5982646          SAN JOSE             0       NaN
# 28  CAPITOL       72761  RTD5982677        SACRAMENTO             1       NaN
# 29  CAPITOL       72761  RTD5982678        SACRAMENTO             1       NaN
# 33  CAPITOL       72761  RTD5982679        SACRAMENTO             1       NaN
# 37  CAPITOL       72761  RTD5982680        SACRAMENTO             1       NaN
# ...

# %%
route = pd.read_csv('routes.txt')

# %%
route
# Out:
#   route_id agency_id  route_short_name route_long_name  route_type  \
# 0  CAPITOL        AM               NaN         CAPITOL           2
#
#    route_color  route_text_color
# 0          NaN               NaN

# %%
AM = route[route['route_id'].isin(AM['route_id'])]

# %%
AM
# Out:
#   route_id agency_id  route_short_name route_long_name  route_type  \
# 0  CAPITOL        AM               NaN         CAPITOL           2
#
#    route_color  route_text_color
# 0          NaN               NaN
