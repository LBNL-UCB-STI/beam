# %%
import pandas as pd

# %%
skimsTransitCrowding = pd.read_csv('1.String _ skimsTransitCrowding.csv.gz')

# %%
overloadedMode = skimsTransitCrowding[skimsTransitCrowding['capacity'] <= skimsTransitCrowding['numberOfPassengers']]

# %%
overloadedMode['firstTwo'] = overloadedMode['vehicleId'].str[:2]
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_1564/4091636193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overloadedMode['firstTwo'] = overloadedMode['vehicleId'].str[:2]

# %%
overloadedMode['lastSeven'] = overloadedMode['vehicleId'].str[-7:]
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_1564/1818584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overloadedMode['lastSeven'] = overloadedMode['vehicleId'].str[-7:]

# %%
overloadedMode
# Out:
#          vehicleId  fromStopIdx  numberOfPassengers  capacity  observations  \
# 86      VT:2223873           11                  77        77             1
# 508     VT:2222844            3                  77        77             1
# 825     VT:2223902            6                  77        77             1
# 989     VT:2223889           31                  77        77             1
# 990     VT:2223912           12                  77        77             1
# ...            ...          ...                 ...       ...           ...
# 102142  VT:2222938            9                  77        77             1
# 102215  VT:2222882           28                  77        77             1
# 102378  VT:2223860           29                  77        77             1
# 102782  VT:2222801            7                  77        77             1
# 102894  VT:2223886            8                  77        77             1
#
#         iterations firstTwo lastSeven
# 86               1       VT   2223873
# 508              1       VT   2222844
# 825              1       VT   2223902
# 989              1       VT   2223889
# 990              1       VT   2223912
# ...            ...      ...       ...
# 102142           1       VT   2222938
# 102215           1       VT   2222882
# 102378           1       VT   2223860
# 102782           1       VT   2222801
# 102894           1       VT   2223886
#
# [759 rows x 8 columns]

# %%
overloadedMode[overloadedMode['firstTwo'] == 'VT']
## The 77 here is actually TRAM-DEFAULT
# Out:
#          vehicleId  fromStopIdx  numberOfPassengers  capacity  observations  \
# 86      VT:2223873           11                  77        77             1
# 508     VT:2222844            3                  77        77             1
# 825     VT:2223902            6                  77        77             1
# 989     VT:2223889           31                  77        77             1
# 990     VT:2223912           12                  77        77             1
# ...            ...          ...                 ...       ...           ...
# 102142  VT:2222938            9                  77        77             1
# 102215  VT:2222882           28                  77        77             1
# 102378  VT:2223860           29                  77        77             1
# 102782  VT:2222801            7                  77        77             1
# 102894  VT:2223886            8                  77        77             1
#
#         iterations firstTwo lastSeven
# 86               1       VT   2223873
# 508              1       VT   2222844
# 825              1       VT   2223902
# 989              1       VT   2223889
# 990              1       VT   2223912
# ...            ...      ...       ...
# 102142           1       VT   2222938
# 102215           1       VT   2222882
# 102378           1       VT   2223860
# 102782           1       VT   2222801
# 102894           1       VT   2223886
#
# [750 rows x 8 columns]

# %%
overloadedMode.groupby('firstTwo').count()

# it's causing more denied trips -- 37% vs 24% before, VTA caused the denied trips for both BA and Tram, how many 
# boardings we should have VTA?
# TRAM-DEFAULT is for VTA light rail??
# Out:
#           vehicleId  fromStopIdx  numberOfPassengers  capacity  observations  \
# firstTwo
# SF                9            9                   9         9             9
# VT              750          750                 750       750           750
#
#           iterations  lastSeven
# firstTwo
# SF                 9          9
# VT               750        750

# %%
trips = pd.read_csv('trips.txt')

# %%
trips
# Out:
#       route_id service_id  trip_id                    trip_headsign  \
# 0           10   Weekdays  2204826  10 METRO LIGHT RAIL VIA AIRPORT
# 1           10   Weekdays  2204834  10 METRO LIGHT RAIL VIA AIRPORT
# 2           10   Weekdays  2204888  10 METRO LIGHT RAIL VIA AIRPORT
# 3           10   Weekdays  2204847  10 METRO LIGHT RAIL VIA AIRPORT
# 4           10   Weekdays  2204889  10 METRO LIGHT RAIL VIA AIRPORT
# ...        ...        ...      ...                              ...
# 8589       914    EXP-410  2319789                          DIRIDON
# 8590       914    EXP-410  2319790     GREAT AMERICA LEVI'S STADIUM
# 8591       914    EXP-410  2319791     GREAT AMERICA LEVI'S STADIUM
# 8592        16   Weekdays  2205801         68 MONTEREY & SAN MARTIN
# 8593       831   Weekdays  2221954                   VIOLET SHUTTLE
#
#       direction_id  block_id  shape_id
# 0                0      1073   10_EB01
# 1                0      1071   10_EB01
# 2                0      1073   10_EB01
# 3                0      1071   10_EB01
# 4                0      1074   10_EB01
# ...            ...       ...       ...
# 8589             1      9170  914_SB04
# 8590             1      9173  914_SB06
# 8591             1      9174  914_SB06
# 8592             1      7102  16_SBSD3
# 8593             1     68312  831_WB02
#
# [8594 rows x 7 columns]

# %%
trip_idlist = list(overloadedMode[overloadedMode['firstTwo'] == 'VT']['lastSeven'])

# %%
VT = trips[trips['trip_id'].isin(overloadedMode[overloadedMode['firstTwo'] == 'VT']['lastSeven'].astype(int))]

# %%
VT
# Out:
#       route_id service_id  trip_id      trip_headsign  direction_id  block_id  \
# 7879       901   Weekdays  2222867  EXPRESS BAYPOINTE             0      9016
# 7888       901   Weekdays  2222802          ALUM ROCK             0      9005
# 7889       901   Weekdays  2222803          ALUM ROCK             0      9006
# 7914       901   Weekdays  2222809          ALUM ROCK             0      9001
# 7924       901   Weekdays  2222827          ALUM ROCK             0      9010
# ...        ...        ...      ...                ...           ...       ...
# 8489       902   Weekdays  2223911         WINCHESTER             1      9046
# 8490       902   Weekdays  2223912         WINCHESTER             1      9036
# 8491       902   Weekdays  2223913         WINCHESTER             1      9037
# 8493       902   Weekdays  2223915         WINCHESTER             1      9044
# 8494       902   Weekdays  2223916         WINCHESTER             1      9045
#
#         shape_id
# 7879  901_NBEX01
# 7888   901_NB01D
# 7889   901_NB01D
# 7914   901_NB01A
# 7924    901_NB01
# ...          ...
# 8489    902_SB01
# 8490    902_SB01
# 8491    902_SB01
# 8493    902_SB01
# 8494    902_SB01
#
# [182 rows x 7 columns]

# %%
route = pd.read_csv('routes.txt')

# %%
route
# Out:
#     route_id agency_id  route_short_name                     route_long_name  \
# 0         10       VTA                10  SANTA CLARA TRANSIT- METRO AIRPORT
# 1        101       VTA               101         CAMDEN & HWY 85 - PALO ALTO
# 2        102       VTA               102          SOUTH SAN JOSE - PALO ALTO
# 3        103       VTA               103               EASTRIDGE - PALO ALTO
# 4        104       VTA               104    PENITENCIA TRANS CTR - PALO ALTO
# ..       ...       ...               ...                                 ...
# 87       911       VTA               911   LRT SANTA TERESA - LEVI'S STADIUM
# 88       912       VTA               912            LRT MOUNTAIN VIEW - GISH
# 89       913       VTA               913     LRT ALUM ROCK TO LEVI'S STADIUM
# 90       914       VTA               914    LRT WINCHESTER TO LEVI'S STADIUM
# 91        95       VTA                95                       LR BUS BRIDGE
#
#     route_desc  route_type  route_url route_color  route_text_color
# 0          NaN           3        NaN         NaN               NaN
# 1          NaN           3        NaN         NaN               NaN
# 2          NaN           3        NaN         NaN               NaN
# 3          NaN           3        NaN         NaN               NaN
# 4          NaN           3        NaN         NaN               NaN
# ..         ...         ...        ...         ...               ...
# 87         NaN           0        NaN         NaN               NaN
# 88         NaN           0        NaN         NaN               NaN
# 89         NaN           0        NaN         NaN               NaN
# 90         NaN           0        NaN         NaN               NaN
# 91         NaN           3        NaN         NaN               NaN
#
# [92 rows x 9 columns]

# %%
VT = route[route['route_id'].isin(VT['route_id'])]

# %%
VT
# Out:
#     route_id agency_id  route_short_name                      route_long_name  \
# 81       901       VTA               901  ALUM ROCK-SANTA TERESA VIA BAYPOINT
# 82       902       VTA               902           MOUNTAIN VIEW - WINCHESTER
#
#     route_desc  route_type  route_url route_color  route_text_color
# 81         NaN           0        NaN      008FD5               NaN
# 82         NaN           0        NaN      7FBF4F               NaN

# %%
## Comes all from tram, but we don't have a place to add capacity for tram-VTA yet. We define a new vehicle type 
## or use TRAM-DEFAULT?
